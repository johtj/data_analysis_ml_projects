# %%
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from matrix_creation import polynomial_features,scale_features_by_intercept_use
from main_methods import OLS_parameters,Ridge_parameters
from errors import MSE,R2
from plotting_exploration import setup_preamble
from plotting_exploration import plot_mse,plot_r2,explore_lambda,explore_polynomial_degree
from plotting_exploration import explore_iterations_GD_methods_ridge,explore_iterations_GD_methods_OLS
from plotting_exploration import explore_n_epochs_stochasticGD_ridge,explore_n_epochs_stochasticGD_OLS

# %%
# No noise
# creating design matrix with polynomial features: p
n_datapoints = 100
standard_deviation = 0.1
p = 15
use_intercept = True


x,y,x_train,x_test,X_train_scaled,X_test_scaled,X_train,X_test,y_train,y_test = setup_preamble(n_datapoints,standard_deviation,p,use_intercept)

# %% [markdown]
# ## Gradient descent

# %%
ns = [10,50,100,1000,10000,100000]
eta = 0.001
lam = 0.01

explore_iterations_GD_methods_ridge(ns,eta,lam,x,y,x_train,x_test,X_train_scaled,X_test_scaled,y_train)

# %%
ns = [10,50,100,1000,10000,100000]
eta = 0.001
lam = 0.01

explore_iterations_GD_methods_OLS(ns,eta,x,y,x_train,x_test,X_train_scaled,X_test_scaled,y_train)

# %% [markdown]
# ## Stochastic Gradient Descent

# %%
eta = 0.001
lam = 0.01
size_minibatch = 10
num_points = len(X_train)
num_epochs = [10,50,100,1000,10000,100000]

explore_n_epochs_stochasticGD_ridge(num_epochs,num_points,size_minibatch,eta,lam,x,y,x_train,x_test,X_train,X_test,y_train)

# %%
eta = 0.001
lam = 0.01
size_minibatch = 10
num_points = len(X_train)
num_epochs = [10,50,100,1000,10000,100000]

explore_n_epochs_stochasticGD_OLS(num_epochs,num_points,size_minibatch,eta,x,y,x_train,x_test,X_train,X_test,y_train)
